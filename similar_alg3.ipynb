# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_pickle("bin/frec_jawiki-latest-pages-articles.pkl")
df
# Out:
#                       Word  Frequency
# 0                        年    3057925
# 1                        日    1879591
# 2                        月    1278188
# 3                        者    1019071
# 4                        人     982168
# ...                    ...        ...
# 10585790          リンクサイクルズ          1
# 10585791       アドクスセンチメートル          1
# 10585792  アドクスアドクスセンゴクエンシス          1
# 10585793              upct          1
# 10585794    ムラーリャデルマルキャンパス          1
#
# [10585795 rows x 2 columns]

# %%
df[df["Frequency"] > 20000]
# Out:
#         Word  Frequency
# 0          年    3057925
# 1          日    1879591
# 2          月    1278188
# 3          者    1019071
# 4          人     982168
# ...      ...        ...
# 2174  アシスタント      20084
# 2175   ドライバー      20071
# 2176      売却      20061
# 2177      知識      20025
# 2178      暗殺      20009
#
# [2179 rows x 2 columns]

# %%
df1 = df[df["Frequency"] >= 1000]
df1 = df1[df1["Frequency"] <= 20000]
plt.hist(df1["Frequency"], bins=100)
# Out:
# (array([2260., 1794., 1387., 1176.,  977.,  898.,  747.,  641.,  619.,
#          510.,  505.,  424.,  446.,  364.,  318.,  343.,  266.,  242.,
#          259.,  221.,  203.,  183.,  201.,  178.,  153.,  166.,  158.,
#          134.,  133.,  142.,  124.,  134.,  111.,  102.,  106.,   83.,
#          100.,   75.,   94.,   93.,   77.,   90.,   79.,   59.,   68.,
#           56.,   71.,   83.,   54.,   73.,   56.,   57.,   66.,   51.,
#           57.,   53.,   58.,   50.,   50.,   54.,   49.,   49.,   46.,
#           41.,   43.,   43.,   47.,   42.,   47.,   42.,   37.,   43.,
#           33.,   34.,   45.,   31.,   32.,   36.,   27.,   23.,   29.,
#           41.,   34.,   28.,   27.,   26.,   28.,   26.,   29.,   25.,
#           17.,   16.,   17.,   19.,   18.,   24.,   25.,   14.,   19.,
#           24.]),
#  array([ 1000.  ,  1189.94,  1379.88,  1569.82,  1759.76,  1949.7 ,
#          2139.64,  2329.58,  2519.52,  2709.46,  2899.4 ,  3089.34,
# ...

# %% [markdown]
# # 単語を知っているか確かめる

# %%
df1 = df[df["Frequency"] > 1]
df100 = df[df["Frequency"] > 100]
df1000 = df[df["Frequency"] > 1000]
df2000 = df[df["Frequency"] > 2000]
df10000 = df[df["Frequency"] > 10000]
df20000 = df[df["Frequency"] > 20000]
df15000 = df[df["Frequency"] > 15000]
df25000 = df[df["Frequency"] > 25000]

df1.tail(20)
df100.tail(20)
df1000.tail(20)
# df2000.tail(20)
# df10000.tail(20)
# df20000.tail(20)
# df15000.tail(20)
df25000.tail(20)
# Out:
#          Word  Frequency
# 21751     マージ       1001
# 21752     ロッソ       1001
# 21753  トワイライト       1001
# 21754      上表       1001
# 21755      小便       1001
# 21756      柴又       1001
# 21757      女系       1001
# 21758  スポーツマン       1001
# 21759      喚起       1001
# 21760      巨塔       1001
# 21761      福住       1001
# 21762      オロ       1001
# 21763      高揚       1001
# 21764      秘訣       1001
# 21765  psvita       1001
# 21766       轍       1001
# 21767      ノラ       1001
# 21768     長谷寺       1001
# 21769      共管       1001
# 21770      外宮       1001
